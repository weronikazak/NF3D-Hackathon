# %%
import numpy as np
import pandas as pd
import glob
import scipy.misc
import tensorflow as tf
import scipy
import os
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split

# %%
BORED_APES_ADDRESS = "0xbc4ca0eda7647a8ab7c2061c2e118a18a936f13d"
KEY = "ckey_773ccb8db17c4884a9ff935d884"

# %% [markdown]
# # BORED APES

# %%
import requests
URL = f"https://api.covalenthq.com/v1/1/tokens/{BORED_APES_ADDRESS}/nft_metadata/123/?quote-currency=USD&format=JSON&key="
res = requests.get(URL + KEY)
res.json()
# Out:
# {'data': {'updated_at': '2022-03-07T16:36:27.978484782Z',
#   'items': [{'contract_decimals': 0,
#     'contract_name': 'BoredApeYachtClub',
#     'contract_ticker_symbol': 'BAYC',
#     'contract_address': '0xbc4ca0eda7647a8ab7c2061c2e118a18a936f13d',
#     'supports_erc': ['erc20'],
#     'logo_url': 'https://logos.covalenthq.com/tokens/1/0xbc4ca0eda7647a8ab7c2061c2e118a18a936f13d.png',
#     'type': 'nft',
#     'nft_data': [{'token_id': '123',
#       'token_balance': '1',
#       'token_url': 'https://ipfs.io/ipfs/QmeSjSinHpPnmXmspMjwiXyN6zS4E9zccariGR3jxcaWtq/123',
#       'supports_erc': ['erc20', 'erc721'],
#       'token_price_wei': None,
#       'token_quote_rate_eth': None,
#       'original_owner': '0x643ce52422b668f0e226dd21b4bb8d3a1fabca51',
#       'external_data': {'name': None,
#        'description': None,
#        'image': 'https://ipfs.io/ipfs/QmVP1tqb9jf6XCkZZXkqGfTAtS8KwXHKHvkePh62zyL65n',
#        'image_256': 'https://image-proxy.svc.prod.covalenthq.com/256,fit,png/https://ipfs.io/ipfs/QmVP1tqb9jf6XCkZZXkqGfTAtS8KwXHKHvkePh62zyL65n',
#        'image_512': 'https://image-proxy.svc.prod.covalenthq.com/512,fit,png/https://ipfs.io/ipfs/QmVP1tqb9jf6XCkZZXkqGfTAtS8KwXHKHvkePh62zyL65n',
#        'image_1024': 'https://image-proxy.svc.prod.covalenthq.com/1024,fit,png/https://ipfs.io/ipfs/QmVP1tqb9jf6XCkZZXkqGfTAtS8KwXHKHvkePh62zyL65n',
#        'animation_url': None,
#        'external_url': None,
#        'attributes': [{'trait_type': 'Clothes', 'value': 'Black Holes T'},
#         {'trait_type': 'Fur', 'value': 'White'},
#         {'trait_type': 'Eyes', 'value': 'Coins'},
#         {'trait_type': 'Background', 'value': 'New Punk Blue'},
#         {'trait_type': 'Mouth', 'value': 'Bored Cigar'},
#         {'trait_type': 'Hat', 'value': 'Spinner Hat'}],
#        'owner': None},
#       'owner': '0x68c4d9e03d7d902053c428ca2d74b612db7f583a',
#       'owner_address': '0x68c4d9e03d7d902053c428ca2d74b612db7f583a',
#       'burned': False}]}],
#   'pagination': None},
#  'error': False,
#  'error_message': None,
#  'error_code': None}

# %% [markdown]
# ## Try an example

# %%
from IPython.display import Image
from IPython.core.display import HTML 

image_url = res.json()["data"]["items"][0]["nft_data"][0]["external_data"]["image"]
Image(url=image_url)
# Out:
# <img src="https://ipfs.io/ipfs/QmVP1tqb9jf6XCkZZXkqGfTAtS8KwXHKHvkePh62zyL65n"/>

# %%
img_data = requests.get(image_url).content
with open('images/123.jpg', 'wb') as handler:
    handler.write(img_data)

# %%
df = pd.DataFrame(columns=["image_id", "trait_type", "value"])

attributes = res.json()["data"]["items"][0]["nft_data"][0]["external_data"]["attributes"]

for attr in attributes:
    df = df.append({
                    "image_id": 123, 
                    "trait_type": attr["trait_type"], 
                    "value": attr["value"]},
                    ignore_index=True)

df
# Out:
#   image_id  trait_type          value
# 0      123     Clothes  Black Holes T
# 1      123         Fur          White
# 2      123        Eyes          Coins
# 3      123  Background  New Punk Blue
# 4      123       Mouth    Bored Cigar
# 5      123         Hat    Spinner Hat

# %% [markdown]
# ## Get full dataset

# %%
df = pd.DataFrame(columns=["image_id", "trait_type", "value"])

for i in range(10_000):
    try:
        URL = f"https://api.covalenthq.com/v1/1/tokens/{BORED_APES_ADDRESS}/nft_metadata/{i}/?quote-currency=USD&format=JSON&key={KEY}"
        res = requests.get(URL)
        
        image_url = res.json()["data"]["items"][0]["nft_data"][0]["external_data"]["image"]
        img_data = requests.get(image_url).content
        with open(f'images//bored_apes/{i}.jpg', 'wb') as handler:
            handler.write(img_data)
            
        attributes = res.json()["data"]["items"][0]["nft_data"][0]["external_data"]["attributes"]

        for attr in attributes:
            df = df.append({
                        "image_id": i, 
                        "trait_type": attr["trait_type"], 
                        "value": attr["value"]},
                        ignore_index=True)
    except:
        print(f"Broke on image {i}")
        df.to_csv(f'bored_apes_{i}.csv')
df.to_csv(f'bored_apes_{i}.csv')
# Out:
# Broke on image 2936
# Broke on image 2978
# Broke on image 2999
# Broke on image 8325

# %% [markdown]
# # CRYPTOPUNKS

# %% [markdown]
# ## Try an example

# %%
KEY_NFTPORT = "f3b6580e-c649-4c07-aa3a-f18f1914b4e5"
CRYPTOPUNKS_ADDRESS = "0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb"
i = 100
URL = f"https://api.nftport.xyz/v0/nfts/{CRYPTOPUNKS_ADDRESS}/{i}?chain=ethereum"
res = requests.get(URL, headers={"Authorization": KEY_NFTPORT})

res.json()
# Out:
# {'response': 'OK',
#  'nft': {'chain': 'ethereum',
#   'contract_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#   'token_id': '100',
#   'metadata_url': None,
#   'metadata': {'name': 'CryptoPunk #100',
#    'description': None,
#    'image': 'https://www.larvalabs.com/cryptopunks/cryptopunk100.png',
#    'opensea_cached_image': 'https://lh3.googleusercontent.com/qteV0m0xYrtt9W7dXUiU9dI3Cpaw6K9NzEU0kirxAJGbvNolYkphznaCXyQrThE4Zlj_AEQNXn2RwFILEN3Af6Q',
#    'animation': None,
#    'opensea_cached_animation': None,
#    'external_url': 'https://www.larvalabs.com/cryptopunks/details/100',
#    'attributes': [{'display_type': None,
#      'max_value': None,
#      'order': None,
#      'trait_count': 3840,
#      'trait_type': 'type',
#      'value': 'Female'},
#     {'display_type': None,
#      'max_value': None,
#      'order': None,
#      'trait_count': 178,
#      'trait_type': 'accessory',
#      'value': 'Tassle Hat'},
#     {'display_type': None,
#      'max_value': None,
#      'order': None,
#      'trait_count': 126,
#      'trait_type': 'accessory',
#      'value': '1 attributes'}]},
#   'file_information': {'height': 336, 'width': 336, 'file_size': 2912},
#   'file_url': 'https://www.larvalabs.com/cryptopunks/cryptopunk100.png',
#   'cached_file_url': 'https://storage.googleapis.com/sentinel-nft/raw-assets/45a8440f21b663397a6df365e000b4cc1877dcee1692dae3751e246eb9a0b86b.png',
#   'mint_date': '2018-02-13T05:00:26.725422',
#   'updated_date': '2022-01-13T22:16:35.168935'},
#  'contract': {'name': 'CRYPTOPUNKS', 'symbol': 'Ͼ', 'type': None}}

# %%
image_url = res.json()["nft"]["cached_file_url"]
# image_url
Image(url=image_url)
# Out:
# <img src="https://storage.googleapis.com/sentinel-nft/raw-assets/45a8440f21b663397a6df365e000b4cc1877dcee1692dae3751e246eb9a0b86b.png"/>

# %%
df = pd.DataFrame(columns=["image_id", "trait_type", "value"])

attributes = res.json()["nft"]["metadata"]["attributes"]

for attr in attributes:
    df = df.append({
                    "image_id": i, 
                    "trait_type": attr["trait_type"], 
                    "value": attr["value"]},
                    ignore_index=True)

df
# Out:
#   image_id trait_type         value
# 0      100       type        Female
# 1      100  accessory    Tassle Hat
# 2      100  accessory  1 attributes

# %%
i = 1
URL = f"https://api.nftport.xyz/v0/nfts/{CRYPTOPUNKS_ADDRESS}?chain=ethereum&page_number={i}&include=metadata"
res = requests.get(URL, headers={"Authorization": KEY_NFTPORT})

# %%
res.json()
# Out:
# {'response': 'OK',
#  'nfts': [{'chain': 'ethereum',
#    'contract_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#    'token_id': '0',
#    'metadata': {'name': 'CryptoPunk #0',
#     'description': None,
#     'image': 'https://www.larvalabs.com/cryptopunks/cryptopunk0.png',
#     'opensea_cached_image': 'https://lh3.googleusercontent.com/loHrK-246FlyQWzT8OONN1tteD2w31sPa3LsUjG_E9Ek2kaSAbodd2plbJKRB5LbwbOtKUzcAcEJEeePCS1lbFB82Q',
#     'animation': None,
#     'opensea_cached_animation': None,
#     'external_url': 'https://www.larvalabs.com/cryptopunks/details/0',
#     'attributes': [{'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 3840,
#       'trait_type': 'type',
#       'value': 'Female'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 271,
#       'trait_type': 'accessory',
#       'value': 'Green Eye Shadow'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 2459,
#       'trait_type': 'accessory',
#       'value': 'Earring'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 147,
#       'trait_type': 'accessory',
#       'value': 'Blonde Bob'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 1535,
#       'trait_type': 'accessory',
#       'value': '3 attributes'}]},
#    'metadata_url': None,
#    'file_url': 'https://www.larvalabs.com/cryptopunks/cryptopunk0.png',
#    'cached_file_url': 'https://storage.googleapis.com/sentinel-nft/raw-assets/12972af803f48315dafa0f8478580a183e55a6c5c4dc2b7aa59e13fd21f34c5b.png',
#    'updated_date': '2022-01-15T03:46:52.092429'},
#   {'chain': 'ethereum',
#    'contract_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#    'token_id': '1',
#    'metadata': {'name': None,
#     'description': None,
#     'image': None,
#     'opensea_cached_image': None,
#     'animation': None,
#     'opensea_cached_animation': None,
#     'external_url': None,
#     'attributes': None},
#    'metadata_url': None,
#    'file_url': 'https://www.larvalabs.com/cryptopunks/cryptopunk1.png',
#    'cached_file_url': 'https://storage.googleapis.com/sentinel-nft/raw-assets/a200bf39b8c8ec73d1f42aaa579c688a37837090e1eed7cfe461be204448d680.png',
#    'updated_date': '2022-01-12T12:02:52.586726'},
#   {'chain': 'ethereum',
#    'contract_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#    'token_id': '10',
#    'metadata': {'name': 'CryptoPunk #10',
#     'description': None,
#     'image': 'https://www.larvalabs.com/cryptopunks/cryptopunk10.png',
#     'opensea_cached_image': 'https://lh3.googleusercontent.com/S_KifnyXY9hotiAnvwzunzJ6kUfD_tou9tBMg8HNdaaXriBozpn4220zOypjCjxg285qSObl8Dtnyz5L4vtOpCFfhg',
#     'animation': None,
#     'opensea_cached_animation': None,
#     'external_url': 'https://www.larvalabs.com/cryptopunks/details/10',
#     'attributes': [{'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 3840,
#       'trait_type': 'type',
#       'value': 'Female'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 441,
#       'trait_type': 'accessory',
#       'value': 'Mohawk'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 266,
#       'trait_type': 'accessory',
#       'value': 'Blue Eye Shadow'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 1253,
#       'trait_type': 'accessory',
#       'value': '2 attributes'}]},
#    'metadata_url': None,
#    'file_url': 'https://www.larvalabs.com/cryptopunks/cryptopunk10.png',
#    'cached_file_url': 'https://storage.googleapis.com/sentinel-nft/raw-assets/ce23f8010e174e35a4a446156f567267d931af4b43bcf424ea0d358089f52ed7.png',
#    'updated_date': '2022-01-15T06:40:56.433237'},
#   {'chain': 'ethereum',
#    'contract_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#    'token_id': '100',
#    'metadata': {'name': 'CryptoPunk #100',
#     'description': None,
#     'image': 'https://www.larvalabs.com/cryptopunks/cryptopunk100.png',
#     'opensea_cached_image': 'https://lh3.googleusercontent.com/qteV0m0xYrtt9W7dXUiU9dI3Cpaw6K9NzEU0kirxAJGbvNolYkphznaCXyQrThE4Zlj_AEQNXn2RwFILEN3Af6Q',
#     'animation': None,
#     'opensea_cached_animation': None,
#     'external_url': 'https://www.larvalabs.com/cryptopunks/details/100',
#     'attributes': [{'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 3840,
#       'trait_type': 'type',
#       'value': 'Female'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 178,
#       'trait_type': 'accessory',
#       'value': 'Tassle Hat'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 126,
#       'trait_type': 'accessory',
#       'value': '1 attributes'}]},
#    'metadata_url': None,
#    'file_url': 'https://www.larvalabs.com/cryptopunks/cryptopunk100.png',
#    'cached_file_url': 'https://storage.googleapis.com/sentinel-nft/raw-assets/45a8440f21b663397a6df365e000b4cc1877dcee1692dae3751e246eb9a0b86b.png',
#    'updated_date': '2022-01-13T22:16:35.168935'},
#   {'chain': 'ethereum',
#    'contract_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#    'token_id': '1000',
#    'metadata': {'name': None,
#     'description': None,
#     'image': None,
#     'opensea_cached_image': None,
#     'animation': None,
#     'opensea_cached_animation': None,
#     'external_url': None,
#     'attributes': None},
#    'metadata_url': None,
#    'file_url': 'https://www.larvalabs.com/cryptopunks/cryptopunk1000.png',
#    'cached_file_url': 'https://storage.googleapis.com/sentinel-nft/raw-assets/c5b74ad9d8359becc57e9b64624e53972d2111e1a9a360e5bf75b978a5710bba.png',
#    'updated_date': '2022-01-12T12:14:04.695087'},
#   {'chain': 'ethereum',
#    'contract_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#    'token_id': '10000',
#    'metadata': {'name': 'CryptoPunk #10000',
#     'description': None,
#     'image': None,
#     'opensea_cached_image': 'https://www.larvalabs.com/cryptopunks/cryptopunk10000.png',
#     'animation': None,
#     'opensea_cached_animation': None,
#     'external_url': 'https://www.larvalabs.com/cryptopunks/details/10000',
#     'attributes': []},
#    'metadata_url': None,
#    'file_url': 'https://www.larvalabs.com/cryptopunks/cryptopunk10000.png',
#    'cached_file_url': None,
#    'updated_date': '2021-12-03T05:34:01.362821'},
#   {'chain': 'ethereum',
#    'contract_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#    'token_id': '1001',
#    'metadata': {'name': 'CryptoPunk #1001',
#     'description': None,
#     'image': 'https://www.larvalabs.com/cryptopunks/cryptopunk1001.png',
#     'opensea_cached_image': 'https://lh3.googleusercontent.com/LsIgdYUBIJl8DN9lN6gQ7TSMQwq99GftvLzjje5oXo89jflA-XZq3hiQXwPtSnzYZf2pgSxLxqyRHVGUwtBuxGkfP45pRrMiGdZ3oA',
#     'animation': None,
#     'opensea_cached_animation': None,
#     'external_url': 'https://www.larvalabs.com/cryptopunks/details/1001',
#     'attributes': [{'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 6039,
#       'trait_type': 'type',
#       'value': 'Male'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 303,
#       'trait_type': 'accessory',
#       'value': 'Peak Spike'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 572,
#       'trait_type': 'accessory',
#       'value': 'Nerd Glasses'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 286,
#       'trait_type': 'accessory',
#       'value': 'Luxurious Beard'}]},
#    'metadata_url': None,
#    'file_url': 'https://www.larvalabs.com/cryptopunks/cryptopunk1001.png',
#    'cached_file_url': 'https://storage.googleapis.com/sentinel-nft/raw-assets/093002aeecfec29f283561d61491910f9a8e0bfd10ee9f65e64ce3f19878f192.png',
#    'updated_date': '2022-01-14T22:30:52.803497'},
#   {'chain': 'ethereum',
#    'contract_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#    'token_id': '1002',
#    'metadata': {'name': 'CryptoPunk #1002',
#     'description': None,
#     'image': 'https://www.larvalabs.com/cryptopunks/cryptopunk1002.png',
#     'opensea_cached_image': 'https://lh3.googleusercontent.com/Pz5TvlSmoG07-F0ASv_EfKIVj3OVxC-Klfk3BxG1e8iJgLA97go7kh4zqsl0wVFZmQVQ4KeNNqrfcr5V2a-fuSBzvg',
#     'animation': None,
#     'opensea_cached_animation': None,
#     'external_url': 'https://www.larvalabs.com/cryptopunks/details/1002',
#     'attributes': [{'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 6039,
#       'trait_type': 'type',
#       'value': 'Male'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 429,
#       'trait_type': 'accessory',
#       'value': 'Mohawk Dark'}]},
#    'metadata_url': None,
#    'file_url': 'https://www.larvalabs.com/cryptopunks/cryptopunk1002.png',
#    'cached_file_url': 'https://storage.googleapis.com/sentinel-nft/raw-assets/2891b796fb25ca74dbf11d0f2a221d74483290ebbea45c94c3e0f7deb0ef6431.png',
#    'updated_date': '2022-01-14T01:40:19.108900'},
#   {'chain': 'ethereum',
#    'contract_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#    'token_id': '1003',
#    'metadata': {'name': 'CryptoPunk #1003',
#     'description': None,
#     'image': 'https://www.larvalabs.com/cryptopunks/cryptopunk1003.png',
#     'opensea_cached_image': 'https://lh3.googleusercontent.com/spcCuVKVKCG_hC_fvYoglgWCxmmGWYjTjjDQ1mRTufRUYQiIdOKSO8RsI-JHsecsXsarhKj4sRoVtZdBHpNUhTvi1Sju2Wbw6sMNNqI',
#     'animation': None,
#     'opensea_cached_animation': None,
#     'external_url': 'https://www.larvalabs.com/cryptopunks/details/1003',
#     'attributes': [{'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 6039,
#       'trait_type': 'type',
#       'value': 'Male'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 572,
#       'trait_type': 'accessory',
#       'value': 'Nerd Glasses'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 442,
#       'trait_type': 'accessory',
#       'value': 'Frumpy Hair'}]},
#    'metadata_url': None,
#    'file_url': 'https://www.larvalabs.com/cryptopunks/cryptopunk1003.png',
#    'cached_file_url': 'https://storage.googleapis.com/sentinel-nft/raw-assets/cce43367e8395c24808a8b409641ca3fb6e4a3729a4e629023e46193c86aa02b.png',
#    'updated_date': '2022-01-14T20:23:39.920732'},
#   {'chain': 'ethereum',
#    'contract_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#    'token_id': '1004',
#    'metadata': {'name': 'CryptoPunk #1004',
#     'description': None,
#     'image': 'https://www.larvalabs.com/cryptopunks/cryptopunk1004.png',
#     'opensea_cached_image': 'https://lh3.googleusercontent.com/gYVShgkOsCZou7-u0qmy2iQrVOFxJASraFcA-6vLGA4h5d56-1LlJWzXzMROZoxQVWEeyCP9SMSwPiGPig_b0xidPdLdHdx6Htnr',
#     'animation': None,
#     'opensea_cached_animation': None,
#     'external_url': 'https://www.larvalabs.com/cryptopunks/details/1004',
#     'attributes': [{'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 3840,
#       'trait_type': 'type',
#       'value': 'Female'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 460,
#       'trait_type': 'accessory',
#       'value': 'Messy Hair'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 617,
#       'trait_type': 'accessory',
#       'value': 'Black Lipstick'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 1247,
#       'trait_type': 'accessory',
#       'value': '2 attributes'}]},
#    'metadata_url': None,
#    'file_url': 'https://www.larvalabs.com/cryptopunks/cryptopunk1004.png',
#    'cached_file_url': 'https://storage.googleapis.com/sentinel-nft/raw-assets/203a815dcb3ce89012a80bc2dd779bbcc8fb122e7434830fd076a4a44f515729.png',
#    'updated_date': '2022-01-14T17:55:31.694967'},
#   {'chain': 'ethereum',
#    'contract_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#    'token_id': '1005',
#    'metadata': {'name': 'CryptoPunk #1005',
#     'description': None,
#     'image': 'https://www.larvalabs.com/cryptopunks/cryptopunk1005.png',
#     'opensea_cached_image': 'https://lh3.googleusercontent.com/qoR1cWuIZzjlrNVcSMAzhrwDvXNtMxaYuDbNqkc_J5WGGqMSrF0wzO7K2MnSCEBLG8G8pZyJPqV7eTGt4wGwret85sbXJBYoAkypdQ',
#     'animation': None,
#     'opensea_cached_animation': None,
#     'external_url': 'https://www.larvalabs.com/cryptopunks/details/1005',
#     'attributes': [{'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 6039,
#       'trait_type': 'type',
#       'value': 'Male'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 527,
#       'trait_type': 'accessory',
#       'value': 'Regular Shades'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 165,
#       'trait_type': 'accessory',
#       'value': 'Purple Hair'}]},
#    'metadata_url': '',
#    'file_url': 'https://www.larvalabs.com/cryptopunks/cryptopunk1005.png',
#    'cached_file_url': 'https://storage.googleapis.com/sentinel-nft/raw-assets/4ce1a9871492cc56857a395164a8f01ea26b091b0f03ae1ab2d62c839eb56e85.png',
#    'updated_date': '2022-01-13T22:16:29.287801'},
#   {'chain': 'ethereum',
#    'contract_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#    'token_id': '1006',
#    'metadata': {'name': 'CryptoPunk #1006',
#     'description': None,
#     'image': 'https://www.larvalabs.com/cryptopunks/cryptopunk1006.png',
#     'opensea_cached_image': 'https://lh3.googleusercontent.com/aVGC7ZXwOMJBqTNfii6YWagUMecWDqEyg2Svu5_9h3afgrGpam3giByajtpSRk3Ax8IZKYatLN_a7776iSZPeJa07_8gKboPEYGGRg',
#     'animation': None,
#     'opensea_cached_animation': None,
#     'external_url': 'https://www.larvalabs.com/cryptopunks/details/1006',
#     'attributes': [{'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 6039,
#       'trait_type': 'type',
#       'value': 'Male'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 527,
#       'trait_type': 'accessory',
#       'value': 'Regular Shades'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 447,
#       'trait_type': 'accessory',
#       'value': 'Wild Hair'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 1256,
#       'trait_type': 'accessory',
#       'value': '2 attributes'}]},
#    'metadata_url': '',
#    'file_url': 'https://www.larvalabs.com/cryptopunks/cryptopunk1006.png',
#    'cached_file_url': 'https://storage.googleapis.com/sentinel-nft/raw-assets/8e66a737d82e0624f8896220d35cc82ffd9e18379589c389281d835a2dbd6467.png',
#    'updated_date': '2022-01-15T12:37:34.149583'},
#   {'chain': 'ethereum',
#    'contract_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#    'token_id': '1007',
#    'metadata': {'name': 'CryptoPunk #1007',
#     'description': None,
#     'image': 'https://www.larvalabs.com/cryptopunks/cryptopunk1007.png',
#     'opensea_cached_image': 'https://lh3.googleusercontent.com/pYJiSfvmytf0SfeVC8MmtAlxI1NYd9Q1PBci0GG2yNJbtvs_YnL_Id1s3AOUqS5myza1Y1bEjDXig_Yp75U71zhZumqSxpNq79xHqA',
#     'animation': None,
#     'opensea_cached_animation': None,
#     'external_url': 'https://www.larvalabs.com/cryptopunks/details/1007',
#     'attributes': [{'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 6039,
#       'trait_type': 'type',
#       'value': 'Male'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 147,
#       'trait_type': 'accessory',
#       'value': 'Vampire Hair'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 2459,
#       'trait_type': 'accessory',
#       'value': 'Earring'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 527,
#       'trait_type': 'accessory',
#       'value': 'Regular Shades'}]},
#    'metadata_url': None,
#    'file_url': 'https://www.larvalabs.com/cryptopunks/cryptopunk1007.png',
#    'cached_file_url': 'https://storage.googleapis.com/sentinel-nft/raw-assets/759a8afd07807b990ec163624c618f43f31740d95f3050fe962c0b5e18f8b171.png',
#    'updated_date': '2022-01-14T01:09:34.486146'},
#   {'chain': 'ethereum',
#    'contract_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#    'token_id': '1008',
#    'metadata': {'name': 'CryptoPunk #1008',
#     'description': None,
#     'image': 'https://www.larvalabs.com/cryptopunks/cryptopunk1008.png',
#     'opensea_cached_image': 'https://lh3.googleusercontent.com/Y4i40Wn3Sz8WmJduk3l7lDuKezp-rVzmZSi6FFtaU0bgxSiI7m8UnMBTDtOdEb71T-KdSwDKirDj7ZcAMxj2ATWCB_gHU15tFbJWPA',
#     'animation': None,
#     'opensea_cached_animation': None,
#     'external_url': 'https://www.larvalabs.com/cryptopunks/details/1008',
#     'attributes': [{'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 6039,
#       'trait_type': 'type',
#       'value': 'Male'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 2459,
#       'trait_type': 'accessory',
#       'value': 'Earring'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 286,
#       'trait_type': 'accessory',
#       'value': 'Luxurious Beard'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 254,
#       'trait_type': 'accessory',
#       'value': 'Cap Forward'}]},
#    'metadata_url': None,
#    'file_url': 'https://www.larvalabs.com/cryptopunks/cryptopunk1008.png',
#    'cached_file_url': 'https://storage.googleapis.com/sentinel-nft/raw-assets/9d12837899fdae652e96a9fdf8745bd26b48742c982b8dccb88be167a638fb84.png',
#    'updated_date': '2022-01-15T11:29:29.309945'},
#   {'chain': 'ethereum',
#    'contract_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#    'token_id': '1009',
#    'metadata': {'name': 'CryptoPunk #1009',
#     'description': None,
#     'image': 'https://www.larvalabs.com/cryptopunks/cryptopunk1009.png',
#     'opensea_cached_image': 'https://lh3.googleusercontent.com/PQw3aSu6BWOztb2BchE1bGmdxk4KDdbzLmgWu-Hh5r2t0ZtQHoft9fyqJay0NQRy9txEeF8_fL82Hr8qlgA-H1vva5qcvurxTaUINg',
#     'animation': None,
#     'opensea_cached_animation': None,
#     'external_url': 'https://www.larvalabs.com/cryptopunks/details/1009',
#     'attributes': [{'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 6039,
#       'trait_type': 'type',
#       'value': 'Male'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 351,
#       'trait_type': 'accessory',
#       'value': 'Cap'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 286,
#       'trait_type': 'accessory',
#       'value': 'Luxurious Beard'}]},
#    'metadata_url': None,
#    'file_url': 'https://www.larvalabs.com/cryptopunks/cryptopunk1009.png',
#    'cached_file_url': 'https://storage.googleapis.com/sentinel-nft/raw-assets/067329ab8124e8c6052002723d1b72c58f28b506fc03ddcdc5203e1e7bf6217b.png',
#    'updated_date': '2022-01-15T14:04:42.102869'},
#   {'chain': 'ethereum',
#    'contract_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#    'token_id': '101',
#    'metadata': {'name': 'CryptoPunk #101',
#     'description': None,
#     'image': 'https://www.larvalabs.com/cryptopunks/cryptopunk101.png',
#     'opensea_cached_image': 'https://lh3.googleusercontent.com/dgDiTkbwxjGgitZne5x_TnsHXrlhBUOg2cf0ec4KLnkXcYt8O5vTfZfI72YmjqpVkZbgkr0KQsOD5vyq_d6Pr38UX7k5Ok14ruD1-yY',
#     'animation': None,
#     'opensea_cached_animation': None,
#     'external_url': 'https://www.larvalabs.com/cryptopunks/details/101',
#     'attributes': [{'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 6039,
#       'trait_type': 'type',
#       'value': 'Male'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 572,
#       'trait_type': 'accessory',
#       'value': 'Nerd Glasses'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 203,
#       'trait_type': 'accessory',
#       'value': 'Police Cap'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 1246,
#       'trait_type': 'accessory',
#       'value': '2 attributes'}]},
#    'metadata_url': None,
#    'file_url': 'https://www.larvalabs.com/cryptopunks/cryptopunk101.png',
#    'cached_file_url': 'https://storage.googleapis.com/sentinel-nft/raw-assets/1b235bccb3feb82e412f55a471a4e15581cdb0e98722d6aef34ebac1a309d719.png',
#    'updated_date': '2022-01-14T13:31:41.078759'},
#   {'chain': 'ethereum',
#    'contract_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#    'token_id': '1010',
#    'metadata': {'name': None,
#     'description': None,
#     'image': None,
#     'opensea_cached_image': None,
#     'animation': None,
#     'opensea_cached_animation': None,
#     'external_url': None,
#     'attributes': None},
#    'metadata_url': None,
#    'file_url': 'https://www.larvalabs.com/cryptopunks/cryptopunk1010.png',
#    'cached_file_url': 'https://storage.googleapis.com/sentinel-nft/raw-assets/33a59a32672847a1afd83bd705babfddadb397b4af23f240f5ea7c72092f9e1b.png',
#    'updated_date': '2022-01-12T11:58:44.223858'},
#   {'chain': 'ethereum',
#    'contract_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#    'token_id': '1011',
#    'metadata': {'name': 'CryptoPunk #1011',
#     'description': None,
#     'image': 'https://www.larvalabs.com/cryptopunks/cryptopunk1011.png',
#     'opensea_cached_image': 'https://lh3.googleusercontent.com/nifadNoVnVynletgXBJzSasENL2xi7LBX7ZF8iR64GyL-0HyckdHAjWptkrpoOlTCpiM9c2UYnt__hhbH5E9diEVj7bGaL3vzMdq6cA',
#     'animation': None,
#     'opensea_cached_animation': None,
#     'external_url': 'https://www.larvalabs.com/cryptopunks/details/1011',
#     'attributes': [{'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 3840,
#       'trait_type': 'type',
#       'value': 'Female'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 463,
#       'trait_type': 'accessory',
#       'value': 'Stringy Hair'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 2459,
#       'trait_type': 'accessory',
#       'value': 'Earring'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 1242,
#       'trait_type': 'accessory',
#       'value': '2 attributes'}]},
#    'metadata_url': None,
#    'file_url': 'https://www.larvalabs.com/cryptopunks/cryptopunk1011.png',
#    'cached_file_url': 'https://storage.googleapis.com/sentinel-nft/raw-assets/5cd6c1a5af7d81833736bcc1ce6bf93f0b9a5d91162a37980a3af6b175dd9b3b.png',
#    'updated_date': '2022-01-14T07:37:32.901565'},
#   {'chain': 'ethereum',
#    'contract_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#    'token_id': '1012',
#    'metadata': {'name': 'CryptoPunk #1012',
#     'description': None,
#     'image': 'https://www.larvalabs.com/cryptopunks/cryptopunk1012.png',
#     'opensea_cached_image': 'https://lh3.googleusercontent.com/kvemzrsxSft0caAXYk1JpRtREZ6OtUcOkvMVeWMAWGGrb7P4nHvRviwFAsQzmwfi3lkKPnWWS-lDpP2_RlWud-fMsGUbNq5tSmekjjE',
#     'animation': None,
#     'opensea_cached_animation': None,
#     'external_url': 'https://www.larvalabs.com/cryptopunks/details/1012',
#     'attributes': [{'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 6039,
#       'trait_type': 'type',
#       'value': 'Male'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 461,
#       'trait_type': 'accessory',
#       'value': 'Eye Patch'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 441,
#       'trait_type': 'accessory',
#       'value': 'Mohawk Thin'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 1241,
#       'trait_type': 'accessory',
#       'value': '2 attributes'}]},
#    'metadata_url': None,
#    'file_url': 'https://www.larvalabs.com/cryptopunks/cryptopunk1012.png',
#    'cached_file_url': 'https://storage.googleapis.com/sentinel-nft/raw-assets/86bec949504e4d890c993e1ca2d294b1e98caaeae4169afcaf157a5c28feb440.png',
#    'updated_date': '2022-01-14T03:17:04.744667'},
#   {'chain': 'ethereum',
#    'contract_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#    'token_id': '1013',
#    'metadata': {'name': 'CryptoPunk #1013',
#     'description': None,
#     'image': 'https://www.larvalabs.com/cryptopunks/cryptopunk1013.png',
#     'opensea_cached_image': 'https://lh3.googleusercontent.com/pyMLVCbsN27FEq_CYyxez2zr98JEM2WXPa4Iivlw1cSy51azeuUz_7BP_GRPHQkLH8RqjlqVN2nFFnInwJFeSpTxFQ',
#     'animation': None,
#     'opensea_cached_animation': None,
#     'external_url': 'https://www.larvalabs.com/cryptopunks/details/1013',
#     'attributes': [{'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 6039,
#       'trait_type': 'type',
#       'value': 'Male'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 382,
#       'trait_type': 'accessory',
#       'value': 'Clown Eyes Green'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 186,
#       'trait_type': 'accessory',
#       'value': 'Fedora'}]},
#    'metadata_url': None,
#    'file_url': 'https://www.larvalabs.com/cryptopunks/cryptopunk1013.png',
#    'cached_file_url': 'https://storage.googleapis.com/sentinel-nft/raw-assets/686b5778cd6a3af1c24cace16ed61b29cf1c69f7cb2dff3856729ab2ed0cdcd8.png',
#    'updated_date': '2022-01-15T04:10:31.737692'},
#   {'chain': 'ethereum',
#    'contract_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#    'token_id': '1014',
#    'metadata': {'name': 'CryptoPunk #1014',
#     'description': None,
#     'image': 'https://www.larvalabs.com/cryptopunks/cryptopunk1014.png',
#     'opensea_cached_image': 'https://lh3.googleusercontent.com/Eep8wSUIV7cCkQM4WGq1SnxiQRZ6n7y3OvdYSfIbjfxVGr6OaxMCx1B_JPPU-QadBrRCz0V9LbsrRRCE4Xw5AmLg',
#     'animation': None,
#     'opensea_cached_animation': None,
#     'external_url': 'https://www.larvalabs.com/cryptopunks/details/1014',
#     'attributes': [{'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 6039,
#       'trait_type': 'type',
#       'value': 'Male'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 286,
#       'trait_type': 'accessory',
#       'value': 'Luxurious Beard'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 254,
#       'trait_type': 'accessory',
#       'value': 'Cap Forward'}]},
#    'metadata_url': None,
#    'file_url': 'https://www.larvalabs.com/cryptopunks/cryptopunk1014.png',
#    'cached_file_url': 'https://storage.googleapis.com/sentinel-nft/raw-assets/ab7554859ecc1f66c7460552640ea95ee85a8110bdb32894e54077ff743d316d.png',
#    'updated_date': '2022-01-14T03:53:48.740633'},
#   {'chain': 'ethereum',
#    'contract_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#    'token_id': '1015',
#    'metadata': {'name': 'CryptoPunk #1015',
#     'description': None,
#     'image': 'https://www.larvalabs.com/cryptopunks/cryptopunk1015.png',
#     'opensea_cached_image': 'https://lh3.googleusercontent.com/i7LqFSJyOiZWcO4xJMGweIqKqj8IatQ1xyVLEAje13hM6pFKo6YiOEyYzsKKp4eJElapTtjxUZUGDoCCrudplpUFq8E3LRpYRS6z',
#     'animation': None,
#     'opensea_cached_animation': None,
#     'external_url': 'https://www.larvalabs.com/cryptopunks/details/1015',
#     'attributes': [{'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 3840,
#       'trait_type': 'type',
#       'value': 'Female'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 460,
#       'trait_type': 'accessory',
#       'value': 'Messy Hair'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 156,
#       'trait_type': 'accessory',
#       'value': 'Silver Chain'}]},
#    'metadata_url': None,
#    'file_url': 'https://www.larvalabs.com/cryptopunks/cryptopunk1015.png',
#    'cached_file_url': 'https://storage.googleapis.com/sentinel-nft/raw-assets/f789f5cf22367debc206494c71e870a3740db4ca39ed17ac2897fecdd35924c4.png',
#    'updated_date': '2022-01-13T22:30:38.305768'},
#   {'chain': 'ethereum',
#    'contract_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#    'token_id': '1016',
#    'metadata': {'name': None,
#     'description': None,
#     'image': None,
#     'opensea_cached_image': None,
#     'animation': None,
#     'opensea_cached_animation': None,
#     'external_url': None,
#     'attributes': None},
#    'metadata_url': None,
#    'file_url': 'https://www.larvalabs.com/cryptopunks/cryptopunk1016.png',
#    'cached_file_url': 'https://storage.googleapis.com/sentinel-nft/raw-assets/abe4eeac98342aae305741113f8eab59bcc4cc7c38aca30b2e88f2f685553b90.png',
#    'updated_date': '2022-01-12T12:13:47.955561'},
#   {'chain': 'ethereum',
#    'contract_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#    'token_id': '1017',
#    'metadata': {'name': 'CryptoPunk #1017',
#     'description': None,
#     'image': 'https://www.larvalabs.com/cryptopunks/cryptopunk1017.png',
#     'opensea_cached_image': 'https://lh3.googleusercontent.com/gRWJhDuHBuvvt2bVbEE3HxcZzQvLBex6a20JSwSl9fLwLobrqW5Mrm6QL_xpymxTLcP5cywYA9oSvlFahIfXFwaWL_tJfXHVGLHbhQ',
#     'animation': None,
#     'opensea_cached_animation': None,
#     'external_url': 'https://www.larvalabs.com/cryptopunks/details/1017',
#     'attributes': [{'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 6039,
#       'trait_type': 'type',
#       'value': 'Male'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 644,
#       'trait_type': 'accessory',
#       'value': 'Mole'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 295,
#       'trait_type': 'accessory',
#       'value': 'Goat'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 115,
#       'trait_type': 'accessory',
#       'value': 'Top Hat'}]},
#    'metadata_url': None,
#    'file_url': 'https://www.larvalabs.com/cryptopunks/cryptopunk1017.png',
#    'cached_file_url': 'https://storage.googleapis.com/sentinel-nft/raw-assets/b4ad7a3effab14fc44efe02583aed8b51f169dcc9ff264558f65373b81daa928.png',
#    'updated_date': '2022-01-13T18:51:09.307111'},
#   {'chain': 'ethereum',
#    'contract_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#    'token_id': '1018',
#    'metadata': {'name': 'CryptoPunk #1018',
#     'description': None,
#     'image': 'https://www.larvalabs.com/cryptopunks/cryptopunk1018.png',
#     'opensea_cached_image': 'https://lh3.googleusercontent.com/nr2PQytCsAti--2u3lWkznJAo1QqUP3wpGkadICKeH4Gly8LKBttsnndmRdywsS_jNlKoRAZ9bMi7-aIv_UKOB3O02lSITJf0LclrKg',
#     'animation': None,
#     'opensea_cached_animation': None,
#     'external_url': 'https://www.larvalabs.com/cryptopunks/details/1018',
#     'attributes': [{'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 6039,
#       'trait_type': 'type',
#       'value': 'Male'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 273,
#       'trait_type': 'accessory',
#       'value': 'Front Beard'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 115,
#       'trait_type': 'accessory',
#       'value': 'Top Hat'}]},
#    'metadata_url': None,
#    'file_url': 'https://www.larvalabs.com/cryptopunks/cryptopunk1018.png',
#    'cached_file_url': 'https://storage.googleapis.com/sentinel-nft/raw-assets/d2cf87d4390f9bcaf78edcda99b555af18e0c76c0eb8efeef32a287252a84b89.png',
#    'updated_date': '2022-01-14T04:20:07.815269'},
#   {'chain': 'ethereum',
#    'contract_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#    'token_id': '1019',
#    'metadata': {'name': 'CryptoPunk #1019',
#     'description': None,
#     'image': 'https://www.larvalabs.com/cryptopunks/cryptopunk1019.png',
#     'opensea_cached_image': 'https://lh3.googleusercontent.com/CeW4hrSWoRXp0aoL6D80GuW0MOGzuc5awaqW1IAxvJkEik6UiEyInIwC9-PsgDlLoeqVKI4sc85GQNjZicWqA9vo6xfgtpmXbNsh',
#     'animation': None,
#     'opensea_cached_animation': None,
#     'external_url': 'https://www.larvalabs.com/cryptopunks/details/1019',
#     'attributes': [{'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 6039,
#       'trait_type': 'type',
#       'value': 'Male'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 282,
#       'trait_type': 'accessory',
#       'value': 'Chinstrap'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 527,
#       'trait_type': 'accessory',
#       'value': 'Regular Shades'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 406,
#       'trait_type': 'accessory',
#       'value': 'Headband'}]},
#    'metadata_url': None,
#    'file_url': 'https://www.larvalabs.com/cryptopunks/cryptopunk1019.png',
#    'cached_file_url': 'https://storage.googleapis.com/sentinel-nft/raw-assets/e33206ff675aa24dd53e12fb4f5bcc43df904deefaf7e9c9d32c0836a9a3f5c3.png',
#    'updated_date': '2022-01-14T00:55:14.691111'},
#   {'chain': 'ethereum',
#    'contract_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#    'token_id': '102',
#    'metadata': {'name': 'CryptoPunk #102',
#     'description': None,
#     'image': 'https://www.larvalabs.com/cryptopunks/cryptopunk102.png',
#     'opensea_cached_image': 'https://lh3.googleusercontent.com/LE8R8uG-TrgREvCGL6WO4_3Wvu52r2HqjHT4mF2MDzxovU61HlII6MjysrOJCM0Ogz1kXpxgXT-5USSwCynVarnjkK5Qzd79GcSqnb8',
#     'animation': None,
#     'opensea_cached_animation': None,
#     'external_url': 'https://www.larvalabs.com/cryptopunks/details/102',
#     'attributes': [{'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 6039,
#       'trait_type': 'type',
#       'value': 'Male'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 147,
#       'trait_type': 'accessory',
#       'value': 'Vampire Hair'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 286,
#       'trait_type': 'accessory',
#       'value': 'Luxurious Beard'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 1246,
#       'trait_type': 'accessory',
#       'value': '2 attributes'}]},
#    'metadata_url': None,
#    'file_url': 'https://www.larvalabs.com/cryptopunks/cryptopunk102.png',
#    'cached_file_url': 'https://storage.googleapis.com/sentinel-nft/raw-assets/3c2342d8a09cccff5437d64d82b21b17e50b9a1c639e1b6ae2fed89a977f0068.png',
#    'updated_date': '2022-01-14T14:50:21.025936'},
#   {'chain': 'ethereum',
#    'contract_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#    'token_id': '1020',
#    'metadata': {'name': None,
#     'description': None,
#     'image': None,
#     'opensea_cached_image': None,
#     'animation': None,
#     'opensea_cached_animation': None,
#     'external_url': None,
#     'attributes': None},
#    'metadata_url': None,
#    'file_url': 'https://www.larvalabs.com/cryptopunks/cryptopunk1020.png',
#    'cached_file_url': 'https://storage.googleapis.com/sentinel-nft/raw-assets/3a3545159bb8b22ad8e77d695adf8cb95aeb71b9edb94897c316c7c35540db91.png',
#    'updated_date': '2022-01-12T11:44:45.282168'},
#   {'chain': 'ethereum',
#    'contract_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#    'token_id': '1021',
#    'metadata': {'name': 'CryptoPunk #1021',
#     'description': None,
#     'image': 'https://www.larvalabs.com/cryptopunks/cryptopunk1021.png',
#     'opensea_cached_image': 'https://lh3.googleusercontent.com/GMu4wsdVxQG9N_7pduBCkSdpkjMX3LDxW6QMpwruncWsiAsfmYja1eSxMVMW4VFkKtCOtaLYcdqw8ftfxZkka9c_CJLkHWghnKQm1w',
#     'animation': None,
#     'opensea_cached_animation': None,
#     'external_url': 'https://www.larvalabs.com/cryptopunks/details/1021',
#     'attributes': [{'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 351,
#       'trait_type': 'accessory',
#       'value': 'Cap'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 461,
#       'trait_type': 'accessory',
#       'value': 'Eye Patch'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 24,
#       'trait_type': 'type',
#       'value': 'Ape'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 1242,
#       'trait_type': 'accessory',
#       'value': '2 attributes'}]},
#    'metadata_url': None,
#    'file_url': 'https://www.larvalabs.com/cryptopunks/cryptopunk1021.png',
#    'cached_file_url': 'https://storage.googleapis.com/sentinel-nft/raw-assets/bdc3e855c600b0b28b92959e3c9f7fecdd1161fb49cfa1d9f874498bb22f3b10.png',
#    'updated_date': '2022-01-14T07:38:48.537059'},
#   {'chain': 'ethereum',
#    'contract_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#    'token_id': '1022',
#    'metadata': {'name': 'CryptoPunk #1022',
#     'description': None,
#     'image': 'https://www.larvalabs.com/cryptopunks/cryptopunk1022.png',
#     'opensea_cached_image': 'https://lh3.googleusercontent.com/An72fu47Eqr5i3wm_v5qtHVrQ_cVH8Pe-PeWq1ee4e5MGoCH6bxJ3T0RighXcXk-PpQnhcEi5iEx6n_cmklwvTQllQ',
#     'animation': None,
#     'opensea_cached_animation': None,
#     'external_url': 'https://www.larvalabs.com/cryptopunks/details/1022',
#     'attributes': [{'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 6039,
#       'trait_type': 'type',
#       'value': 'Male'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 644,
#       'trait_type': 'accessory',
#       'value': 'Mole'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 441,
#       'trait_type': 'accessory',
#       'value': 'Mohawk Thin'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 1239,
#       'trait_type': 'accessory',
#       'value': '2 attributes'}]},
#    'metadata_url': None,
#    'file_url': 'https://www.larvalabs.com/cryptopunks/cryptopunk1022.png',
#    'cached_file_url': 'https://storage.googleapis.com/sentinel-nft/raw-assets/701f80fb0d947fa315308617fb617446cc5fd9d4b1a5d575c426ce8636c6702f.png',
#    'updated_date': '2022-01-13T18:51:14.155577'},
#   {'chain': 'ethereum',
#    'contract_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#    'token_id': '1023',
#    'metadata': {'name': 'CryptoPunk #1023',
#     'description': None,
#     'image': 'https://www.larvalabs.com/cryptopunks/cryptopunk1023.png',
#     'opensea_cached_image': 'https://lh3.googleusercontent.com/6yQFoujT674rbX6eFHzbY-BuEweAjN9xDd3cjAw4lJz-45WjN8pvgm9t9LspJnGtEEqRZBDfI1qsGCSLweM_tJyxRX4aX-3lOj3StQ',
#     'animation': None,
#     'opensea_cached_animation': None,
#     'external_url': 'https://www.larvalabs.com/cryptopunks/details/1023',
#     'attributes': [{'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 3840,
#       'trait_type': 'type',
#       'value': 'Female'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 696,
#       'trait_type': 'accessory',
#       'value': 'Hot Lipstick'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 406,
#       'trait_type': 'accessory',
#       'value': 'Headband'}]},
#    'metadata_url': None,
#    'file_url': 'https://www.larvalabs.com/cryptopunks/cryptopunk1023.png',
#    'cached_file_url': 'https://storage.googleapis.com/sentinel-nft/raw-assets/6286cc87273ccdba0a5216200ce50fde8353dbebcb7353a8818c155b17594fa2.png',
#    'updated_date': '2022-01-14T18:56:18.432807'},
#   {'chain': 'ethereum',
#    'contract_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#    'token_id': '1024',
#    'metadata': {'name': 'CryptoPunk #1024',
#     'description': None,
#     'image': 'https://www.larvalabs.com/cryptopunks/cryptopunk1024.png',
#     'opensea_cached_image': 'https://lh3.googleusercontent.com/NTWXT0jzCpc6m1D8rdIhkGCG_8lD8Ea4Zf5IA8MtyACQDmKvwFUwo3YlQT_TBR08Ru8AlRzWfaMo564dybuiIN01eIR5TBQXjZVG',
#     'animation': None,
#     'opensea_cached_animation': None,
#     'external_url': 'https://www.larvalabs.com/cryptopunks/details/1024',
#     'attributes': [{'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 3840,
#       'trait_type': 'type',
#       'value': 'Female'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 2459,
#       'trait_type': 'accessory',
#       'value': 'Earring'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 696,
#       'trait_type': 'accessory',
#       'value': 'Hot Lipstick'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 447,
#       'trait_type': 'accessory',
#       'value': 'Wild Hair'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 384,
#       'trait_type': 'accessory',
#       'value': 'Clown Eyes Blue'}]},
#    'metadata_url': None,
#    'file_url': 'https://www.larvalabs.com/cryptopunks/cryptopunk1024.png',
#    'cached_file_url': 'https://storage.googleapis.com/sentinel-nft/raw-assets/798a96a1596ff509e0d87c4401052281865d4ac91e47a0c8c733b47f9276748b.png',
#    'updated_date': '2022-01-15T14:28:16.343059'},
#   {'chain': 'ethereum',
#    'contract_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#    'token_id': '1025',
#    'metadata': {'name': 'CryptoPunk #1025',
#     'description': None,
#     'image': 'https://www.larvalabs.com/cryptopunks/cryptopunk1025.png',
#     'opensea_cached_image': 'https://lh3.googleusercontent.com/qSoBaQXy8vjaQNCqPT_jIGpCvUXBaNmn8o1Pzn1647IqVcvputysBcKfuor1gQvfecG4RUxRWTk0B8emXLJFunzCKnGDDcmF0Ldv2Q',
#     'animation': None,
#     'opensea_cached_animation': None,
#     'external_url': 'https://www.larvalabs.com/cryptopunks/details/1025',
#     'attributes': [{'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 6039,
#       'trait_type': 'type',
#       'value': 'Male'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 2459,
#       'trait_type': 'accessory',
#       'value': 'Earring'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 481,
#       'trait_type': 'accessory',
#       'value': 'Bandana'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 1253,
#       'trait_type': 'accessory',
#       'value': '2 attributes'}]},
#    'metadata_url': None,
#    'file_url': 'https://www.larvalabs.com/cryptopunks/cryptopunk1025.png',
#    'cached_file_url': 'https://storage.googleapis.com/sentinel-nft/raw-assets/efc77197b5c76f92ce06018e03ed214e1c31e6e949771a6fb2a0dedec9e056ed.png',
#    'updated_date': '2022-01-15T08:58:44.249771'},
#   {'chain': 'ethereum',
#    'contract_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#    'token_id': '1026',
#    'metadata': {'name': 'CryptoPunk #1026',
#     'description': None,
#     'image': 'https://www.larvalabs.com/cryptopunks/cryptopunk1026.png',
#     'opensea_cached_image': 'https://lh3.googleusercontent.com/gNZiKaiSVlCE26rSPJM0_mCR5hPeJdD0mawxRwUVQTxnVrmLr5tyPyPSDpASeV2LydU6Umy5AQrf99uAjMHV4YRrnmjuozddWPoKkms',
#     'animation': None,
#     'opensea_cached_animation': None,
#     'external_url': 'https://www.larvalabs.com/cryptopunks/details/1026',
#     'attributes': [{'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 6039,
#       'trait_type': 'type',
#       'value': 'Male'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 303,
#       'trait_type': 'accessory',
#       'value': 'Peak Spike'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 644,
#       'trait_type': 'accessory',
#       'value': 'Mole'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 384,
#       'trait_type': 'accessory',
#       'value': 'Clown Eyes Blue'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 1532,
#       'trait_type': 'accessory',
#       'value': '3 attributes'}]},
#    'metadata_url': None,
#    'file_url': 'https://www.larvalabs.com/cryptopunks/cryptopunk1026.png',
#    'cached_file_url': 'https://storage.googleapis.com/sentinel-nft/raw-assets/75b2f96339b625c80385ec6c298c5221e3b20d4034742a0349ed9785b5099eda.png',
#    'updated_date': '2022-01-15T00:22:53.599892'},
#   {'chain': 'ethereum',
#    'contract_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#    'token_id': '1027',
#    'metadata': {'name': None,
#     'description': None,
#     'image': None,
#     'opensea_cached_image': None,
#     'animation': None,
#     'opensea_cached_animation': None,
#     'external_url': None,
#     'attributes': None},
#    'metadata_url': None,
#    'file_url': 'https://www.larvalabs.com/cryptopunks/cryptopunk1027.png',
#    'cached_file_url': 'https://storage.googleapis.com/sentinel-nft/raw-assets/0e56b5776831702ace9742e19f2691522944abcde2453ac7a405041b3fda8e14.png',
#    'updated_date': '2022-01-12T11:46:34.818483'},
#   {'chain': 'ethereum',
#    'contract_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#    'token_id': '1028',
#    'metadata': {'name': 'CryptoPunk #1028',
#     'description': None,
#     'image': 'https://www.larvalabs.com/cryptopunks/cryptopunk1028.png',
#     'opensea_cached_image': 'https://lh3.googleusercontent.com/bO8_j6yLoFNN5kVNds5EvaF-LA8OXXc5wE-LQKidUMzKVXSOvVwc9-ZLCOk98Y37ODRhECp4p-BBNK7iuN7sfDYn',
#     'animation': None,
#     'opensea_cached_animation': None,
#     'external_url': 'https://www.larvalabs.com/cryptopunks/details/1028',
#     'attributes': [{'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 6039,
#       'trait_type': 'type',
#       'value': 'Male'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 535,
#       'trait_type': 'accessory',
#       'value': 'Big Shades'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 441,
#       'trait_type': 'accessory',
#       'value': 'Mohawk Thin'}]},
#    'metadata_url': '',
#    'file_url': 'https://www.larvalabs.com/cryptopunks/cryptopunk1028.png',
#    'cached_file_url': 'https://storage.googleapis.com/sentinel-nft/raw-assets/e8265bebb86d914ca19d34714165d228a03615bae51c677369071e790e85aaf8.png',
#    'updated_date': '2022-01-15T02:18:47.597155'},
#   {'chain': 'ethereum',
#    'contract_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#    'token_id': '1029',
#    'metadata': {'name': 'CryptoPunk #1029',
#     'description': None,
#     'image': 'https://www.larvalabs.com/cryptopunks/cryptopunk1029.png',
#     'opensea_cached_image': 'https://lh3.googleusercontent.com/nuFxUNpkoWq_sS0kdiLn8uTThSq1kmUm0K85k8VxKwn_hiB1JZJ4mPtMQUcOQVH91UCcplEAPVUUhwRKRuY5gkabQg',
#     'animation': None,
#     'opensea_cached_animation': None,
#     'external_url': 'https://www.larvalabs.com/cryptopunks/details/1029',
#     'attributes': [{'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 6039,
#       'trait_type': 'type',
#       'value': 'Male'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 535,
#       'trait_type': 'accessory',
#       'value': 'Horned Rim Glasses'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 288,
#       'trait_type': 'accessory',
#       'value': 'Mustache'},
# ...
#    'cached_file_url': 'https://storage.googleapis.com/sentinel-nft/raw-assets/388fe7ab642f37aaf51fffd4482181c07be3203740dc86f789e284a8d3e4dec7.png',
#    'updated_date': '2022-01-14T09:07:07.953004'},
#   {'chain': 'ethereum',
#    'contract_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#    'token_id': '1031',
#    'metadata': {'name': 'CryptoPunk #1031',
#     'description': None,
#     'image': 'https://www.larvalabs.com/cryptopunks/cryptopunk1031.png',
#     'opensea_cached_image': 'https://lh3.googleusercontent.com/CXQMuN3fRhfe-EiBvPgLHnLJoEgeeqUzBcLX0cwB4a73Uwt9fobSXVAR3hlUT9JJp1L1e_BHueZ9xn2kndHlVG5tg96MsHuiHlmHLSI',
#     'animation': None,
#     'opensea_cached_animation': None,
#     'external_url': 'https://www.larvalabs.com/cryptopunks/details/1031',
#     'attributes': [{'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 6039,
#       'trait_type': 'type',
#       'value': 'Male'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 378,
#       'trait_type': 'accessory',
#       'value': 'Small Shades'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 254,
#       'trait_type': 'accessory',
#       'value': 'Cap Forward'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 1251,
#       'trait_type': 'accessory',
#       'value': '2 attributes'}]},
#    'metadata_url': None,
#    'file_url': 'https://www.larvalabs.com/cryptopunks/cryptopunk1031.png',
#    'cached_file_url': 'https://storage.googleapis.com/sentinel-nft/raw-assets/17bf9de8d5db10ea5d3c02c7034f676f45ed5d77c215fac9aae2bc8abc900c94.png',
#    'updated_date': '2022-01-15T01:05:19.507834'},
#   {'chain': 'ethereum',
#    'contract_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#    'token_id': '1032',
#    'metadata': {'name': 'CryptoPunk #1032',
#     'description': None,
#     'image': 'https://www.larvalabs.com/cryptopunks/cryptopunk1032.png',
#     'opensea_cached_image': 'https://lh3.googleusercontent.com/Y18HKkL43znkyri7RViUW1DtdtwC8_fxZh22RwHgNTjnv4Q7oQ8W3gTYmwNzp_CsjAv9nc34-a27yhzlXoSQrWZa',
#     'animation': None,
#     'opensea_cached_animation': None,
#     'external_url': 'https://www.larvalabs.com/cryptopunks/details/1032',
#     'attributes': [{'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 3840,
#       'trait_type': 'type',
#       'value': 'Female'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 572,
#       'trait_type': 'accessory',
#       'value': 'Nerd Glasses'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 148,
#       'trait_type': 'accessory',
#       'value': 'Straight Hair Dark'}]},
#    'metadata_url': None,
#    'file_url': 'https://www.larvalabs.com/cryptopunks/cryptopunk1032.png',
#    'cached_file_url': 'https://storage.googleapis.com/sentinel-nft/raw-assets/fbc3b96ac5cfae832e1ef89d4d42d6415934f827842d9d76143d3daae01cf5a3.png',
#    'updated_date': '2022-01-13T20:24:30.616919'},
#   {'chain': 'ethereum',
#    'contract_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#    'token_id': '1033',
#    'metadata': {'name': 'CryptoPunk #1033',
#     'description': None,
#     'image': 'https://www.larvalabs.com/cryptopunks/cryptopunk1033.png',
#     'opensea_cached_image': 'https://lh3.googleusercontent.com/1GlLFc6ef3kmNJ4-sygYAYEjUy6xQCUhK328UcfNXxlbmkkHIYNw6w4zna4HPu2OyE7fKQS9XtUJiADFvH434COks4L1VVe-cBU_',
#     'animation': None,
#     'opensea_cached_animation': None,
#     'external_url': 'https://www.larvalabs.com/cryptopunks/details/1033',
#     'attributes': [{'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 3840,
#       'trait_type': 'type',
#       'value': 'Female'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 460,
#       'trait_type': 'accessory',
#       'value': 'Messy Hair'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 696,
#       'trait_type': 'accessory',
#       'value': 'Hot Lipstick'}]},
#    'metadata_url': None,
#    'file_url': 'https://www.larvalabs.com/cryptopunks/cryptopunk1033.png',
#    'cached_file_url': 'https://storage.googleapis.com/sentinel-nft/raw-assets/1ff1e1c6ad79c9d8850fddba0049a604c2e2cb815d9075a88c646e8d13d7049c.png',
#    'updated_date': '2022-01-14T13:32:10.745311'},
#   {'chain': 'ethereum',
#    'contract_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#    'token_id': '1034',
#    'metadata': {'name': 'CryptoPunk #1034',
#     'description': None,
#     'image': 'https://www.larvalabs.com/cryptopunks/cryptopunk1034.png',
#     'opensea_cached_image': 'https://lh3.googleusercontent.com/5o9h-aiXNQS0vB1s95r_V0MqDoY-52dmtBfYn46gOzRgj99RJk6LwvgzAeiDu9X_pMfpm841mvI2J7v2MfPfAyaFUOU5WDLueiFOTpc',
#     'animation': None,
#     'opensea_cached_animation': None,
#     'external_url': 'https://www.larvalabs.com/cryptopunks/details/1034',
#     'attributes': [{'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 6039,
#       'trait_type': 'type',
#       'value': 'Male'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 2459,
#       'trait_type': 'accessory',
#       'value': 'Earring'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 535,
#       'trait_type': 'accessory',
#       'value': 'Big Shades'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 259,
#       'trait_type': 'accessory',
#       'value': 'Hoodie'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 289,
#       'trait_type': 'accessory',
#       'value': 'Normal Beard Black'}]},
#    'metadata_url': None,
#    'file_url': 'https://www.larvalabs.com/cryptopunks/cryptopunk1034.png',
#    'cached_file_url': 'https://storage.googleapis.com/sentinel-nft/raw-assets/7a543f98f88f0ae81cfc249eb772a16dc65c3fa5c2a7bf28b2dd735f2ac37945.png',
#    'updated_date': '2022-01-15T05:37:39.682917'},
#   {'chain': 'ethereum',
#    'contract_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#    'token_id': '1035',
#    'metadata': {'name': 'CryptoPunk #1035',
#     'description': None,
#     'image': 'https://www.larvalabs.com/cryptopunks/cryptopunk1035.png',
#     'opensea_cached_image': 'https://lh3.googleusercontent.com/hIkHSarxzoQz2mchcnx8yhSv8KTvysg9eDxX126EmgplxyjIUsQ4yjAj3LpYVBojFd2heYAO5BvQYwDOTotrdTQq7otrSb2HEGHd',
#     'animation': None,
#     'opensea_cached_animation': None,
#     'external_url': 'https://www.larvalabs.com/cryptopunks/details/1035',
#     'attributes': [{'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 3840,
#       'trait_type': 'type',
#       'value': 'Female'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 617,
#       'trait_type': 'accessory',
#       'value': 'Black Lipstick'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 447,
#       'trait_type': 'accessory',
#       'value': 'Wild Hair'}]},
#    'metadata_url': None,
#    'file_url': 'https://www.larvalabs.com/cryptopunks/cryptopunk1035.png',
#    'cached_file_url': 'https://storage.googleapis.com/sentinel-nft/raw-assets/3fb065f69e5e67b5060a366d8ef053b5f0aa421900b96582dff32046039806a0.png',
#    'updated_date': '2022-01-14T00:31:46.424943'},
#   {'chain': 'ethereum',
#    'contract_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#    'token_id': '1036',
#    'metadata': {'name': 'CryptoPunk #1036',
#     'description': None,
#     'image': 'https://www.larvalabs.com/cryptopunks/cryptopunk1036.png',
#     'opensea_cached_image': 'https://lh3.googleusercontent.com/NMdiDIcOZuQUG23mwbXfsqcwAkUUgHLheR1F4ryjSH_w7vrJZmk4A3Z1JC1zZ_mQm-73FS591hzAXUWJsgiUqcLyfw',
#     'animation': None,
#     'opensea_cached_animation': None,
#     'external_url': 'https://www.larvalabs.com/cryptopunks/details/1036',
#     'attributes': [{'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 6039,
#       'trait_type': 'type',
#       'value': 'Male'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 502,
#       'trait_type': 'accessory',
#       'value': 'Classic Shades'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 441,
#       'trait_type': 'accessory',
#       'value': 'Mohawk Thin'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 1241,
#       'trait_type': 'accessory',
#       'value': '2 attributes'}]},
#    'metadata_url': None,
#    'file_url': 'https://www.larvalabs.com/cryptopunks/cryptopunk1036.png',
#    'cached_file_url': 'https://storage.googleapis.com/sentinel-nft/raw-assets/bb8df236dfd87cff21b4e5ea74ac9271d5596de0a59b3c20b5ebf04b389a1ef7.png',
#    'updated_date': '2022-01-14T05:04:59.698208'},
#   {'chain': 'ethereum',
#    'contract_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#    'token_id': '1037',
#    'metadata': {'name': 'CryptoPunk #1037',
#     'description': None,
#     'image': 'https://www.larvalabs.com/cryptopunks/cryptopunk1037.png',
#     'opensea_cached_image': 'https://lh3.googleusercontent.com/W6q_szrtmO_z6Z0XiFN4u9-ZbmsgbTFzhEEO-Qh7xfTIc__-761edgWK8U_bOeezIg-PG_KQDQS7Jur2GfjmBZqgmtUC-yavkwOtAA',
#     'animation': None,
#     'opensea_cached_animation': None,
#     'external_url': 'https://www.larvalabs.com/cryptopunks/details/1037',
#     'attributes': [{'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 3840,
#       'trait_type': 'type',
#       'value': 'Female'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 266,
#       'trait_type': 'accessory',
#       'value': 'Blue Eye Shadow'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 68,
#       'trait_type': 'accessory',
#       'value': 'Orange Side'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 1249,
#       'trait_type': 'accessory',
#       'value': '2 attributes'}]},
#    'metadata_url': None,
#    'file_url': 'https://www.larvalabs.com/cryptopunks/cryptopunk1037.png',
#    'cached_file_url': 'https://storage.googleapis.com/sentinel-nft/raw-assets/d527ca65428db5cd8b236ce2513a075a2b0fbd6fd4a5d6350597789e0545499a.png',
#    'updated_date': '2022-01-14T23:26:10.297766'},
#   {'chain': 'ethereum',
#    'contract_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#    'token_id': '1038',
#    'metadata': {'name': None,
#     'description': None,
#     'image': None,
#     'opensea_cached_image': None,
#     'animation': None,
#     'opensea_cached_animation': None,
#     'external_url': None,
#     'attributes': None},
#    'metadata_url': None,
#    'file_url': 'https://www.larvalabs.com/cryptopunks/cryptopunk1038.png',
#    'cached_file_url': 'https://storage.googleapis.com/sentinel-nft/raw-assets/9a2b9716502c807fdf1f40d3349bc586eab05bc7480a0d1f2cfb36c31a6e306b.png',
#    'updated_date': '2022-01-12T11:49:02.154601'},
#   {'chain': 'ethereum',
#    'contract_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#    'token_id': '1039',
#    'metadata': {'name': 'CryptoPunk #1039',
#     'description': None,
#     'image': 'https://www.larvalabs.com/cryptopunks/cryptopunk1039.png',
#     'opensea_cached_image': 'https://lh3.googleusercontent.com/vmYM_LPbMmBU_MB_jwUMeMfS3h0eACydR441WLSIEDLN3Lc6joDzrreM-aGK0be5avAkRW3LbhQsxz8B8EItSaGmFTLffmeqGhZmP9k',
#     'animation': None,
#     'opensea_cached_animation': None,
#     'external_url': 'https://www.larvalabs.com/cryptopunks/details/1039',
#     'attributes': [{'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 3840,
#       'trait_type': 'type',
#       'value': 'Female'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 460,
#       'trait_type': 'accessory',
#       'value': 'Messy Hair'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 696,
#       'trait_type': 'accessory',
#       'value': 'Hot Lipstick'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 384,
#       'trait_type': 'accessory',
#       'value': 'Clown Eyes Blue'}]},
#    'metadata_url': None,
#    'file_url': 'https://www.larvalabs.com/cryptopunks/cryptopunk1039.png',
#    'cached_file_url': 'https://storage.googleapis.com/sentinel-nft/raw-assets/c66ea85698d371352190a8ad2df3b86962c649006cc5ef77d2fc3eaa602a4371.png',
#    'updated_date': '2022-01-14T19:56:45.457208'},
#   {'chain': 'ethereum',
#    'contract_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#    'token_id': '104',
#    'metadata': {'name': 'CryptoPunk #104',
#     'description': None,
#     'image': 'https://www.larvalabs.com/cryptopunks/cryptopunk104.png',
#     'opensea_cached_image': 'https://lh3.googleusercontent.com/SiRgzYbLOrWzffkyL-4C5miqG3xHYftAot7WU8e6b2_bhPc1JAGZJs77Q6gbQfdTrgtu-fyYuUWso6Nirdi-4Gked_Y0OC6LaXzcgb8',
#     'animation': None,
#     'opensea_cached_animation': None,
#     'external_url': 'https://www.larvalabs.com/cryptopunks/details/104',
#     'attributes': [{'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 6039,
#       'trait_type': 'type',
#       'value': 'Male'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 2459,
#       'trait_type': 'accessory',
#       'value': 'Earring'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 461,
#       'trait_type': 'accessory',
#       'value': 'Eye Patch'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 289,
#       'trait_type': 'accessory',
#       'value': 'Normal Beard Black'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 414,
#       'trait_type': 'accessory',
#       'value': 'Crazy Hair'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 536,
#       'trait_type': 'accessory',
#       'value': '4 attributes'}]},
#    'metadata_url': None,
#    'file_url': 'https://www.larvalabs.com/cryptopunks/cryptopunk104.png',
#    'cached_file_url': 'https://storage.googleapis.com/sentinel-nft/raw-assets/b4a4b672384c599d7dce9c8a24a18703111d9c59ba1ad42041686b4bdf0df525.png',
#    'updated_date': '2022-01-15T03:56:20.083949'},
#   {'chain': 'ethereum',
#    'contract_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#    'token_id': '1040',
#    'metadata': {'name': 'CryptoPunk #1040',
#     'description': None,
#     'image': 'https://www.larvalabs.com/cryptopunks/cryptopunk1040.png',
#     'opensea_cached_image': 'https://lh3.googleusercontent.com/SvpXnOjajxBApu2o4hr3Qa1VyVmkPhjuzo8Fq7lTNOwZymZkJ2VjU43BIVIofhz9JZHr-hNJpLWJou4Oky7cKOuuFuqYACOx0ttD3w',
#     'animation': None,
#     'opensea_cached_animation': None,
#     'external_url': 'https://www.larvalabs.com/cryptopunks/details/1040',
#     'attributes': [{'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 3840,
#       'trait_type': 'type',
#       'value': 'Female'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 2459,
#       'trait_type': 'accessory',
#       'value': 'Earring'},
#      {'display_type': None,
#       'max_value': None,
#       'order': None,
#       'trait_count': 429,
#       'trait_type': 'accessory',
#       'value': 'Mohawk Dark'}]},
#    'metadata_url': None,
#    'file_url': 'https://www.larvalabs.com/cryptopunks/cryptopunk1040.png',
#    'cached_file_url': 'https://storage.googleapis.com/sentinel-nft/raw-assets/7814b42b4464fe43278ebb97a382b77feb32dcf8ac82678117e0dcadd06be75f.png',
#    'updated_date': '2022-01-15T12:52:25.059396'}],
#  'contract': {'name': 'CRYPTOPUNKS', 'symbol': 'Ͼ', 'type': None},
#  'total': 10003}

# %%
for nft in res.json()["nfts"]:
    print(nft["token_id"])
    print(nft["cached_file_url"])
    try:
        for attr in nft["metadata"]["attributes"]:
            print(attr["trait_type"], attr["value"])        
    except:
        continue
# Out:
# 0
# https://storage.googleapis.com/sentinel-nft/raw-assets/12972af803f48315dafa0f8478580a183e55a6c5c4dc2b7aa59e13fd21f34c5b.png
# type Female
# accessory Green Eye Shadow
# accessory Earring
# accessory Blonde Bob
# accessory 3 attributes
# 1
# https://storage.googleapis.com/sentinel-nft/raw-assets/a200bf39b8c8ec73d1f42aaa579c688a37837090e1eed7cfe461be204448d680.png
# 10
# https://storage.googleapis.com/sentinel-nft/raw-assets/ce23f8010e174e35a4a446156f567267d931af4b43bcf424ea0d358089f52ed7.png
# type Female
# accessory Mohawk
# accessory Blue Eye Shadow
# accessory 2 attributes
# 100
# https://storage.googleapis.com/sentinel-nft/raw-assets/45a8440f21b663397a6df365e000b4cc1877dcee1692dae3751e246eb9a0b86b.png
# type Female
# accessory Tassle Hat
# accessory 1 attributes
# 1000
# https://storage.googleapis.com/sentinel-nft/raw-assets/c5b74ad9d8359becc57e9b64624e53972d2111e1a9a360e5bf75b978a5710bba.png
# 10000
# None
# 1001
# https://storage.googleapis.com/sentinel-nft/raw-assets/093002aeecfec29f283561d61491910f9a8e0bfd10ee9f65e64ce3f19878f192.png
# type Male
# accessory Peak Spike
# accessory Nerd Glasses
# accessory Luxurious Beard
# 1002
# https://storage.googleapis.com/sentinel-nft/raw-assets/2891b796fb25ca74dbf11d0f2a221d74483290ebbea45c94c3e0f7deb0ef6431.png
# type Male
# accessory Mohawk Dark
# 1003
# https://storage.googleapis.com/sentinel-nft/raw-assets/cce43367e8395c24808a8b409641ca3fb6e4a3729a4e629023e46193c86aa02b.png
# type Male
# accessory Nerd Glasses
# accessory Frumpy Hair
# 1004
# https://storage.googleapis.com/sentinel-nft/raw-assets/203a815dcb3ce89012a80bc2dd779bbcc8fb122e7434830fd076a4a44f515729.png
# type Female
# accessory Messy Hair
# accessory Black Lipstick
# accessory 2 attributes
# 1005
# https://storage.googleapis.com/sentinel-nft/raw-assets/4ce1a9871492cc56857a395164a8f01ea26b091b0f03ae1ab2d62c839eb56e85.png
# type Male
# accessory Regular Shades
# accessory Purple Hair
# 1006
# https://storage.googleapis.com/sentinel-nft/raw-assets/8e66a737d82e0624f8896220d35cc82ffd9e18379589c389281d835a2dbd6467.png
# type Male
# accessory Regular Shades
# accessory Wild Hair
# accessory 2 attributes
# 1007
# https://storage.googleapis.com/sentinel-nft/raw-assets/759a8afd07807b990ec163624c618f43f31740d95f3050fe962c0b5e18f8b171.png
# type Male
# accessory Vampire Hair
# accessory Earring
# accessory Regular Shades
# 1008
# https://storage.googleapis.com/sentinel-nft/raw-assets/9d12837899fdae652e96a9fdf8745bd26b48742c982b8dccb88be167a638fb84.png
# type Male
# accessory Earring
# accessory Luxurious Beard
# accessory Cap Forward
# 1009
# https://storage.googleapis.com/sentinel-nft/raw-assets/067329ab8124e8c6052002723d1b72c58f28b506fc03ddcdc5203e1e7bf6217b.png
# type Male
# accessory Cap
# accessory Luxurious Beard
# 101
# https://storage.googleapis.com/sentinel-nft/raw-assets/1b235bccb3feb82e412f55a471a4e15581cdb0e98722d6aef34ebac1a309d719.png
# type Male
# accessory Nerd Glasses
# accessory Police Cap
# accessory 2 attributes
# 1010
# https://storage.googleapis.com/sentinel-nft/raw-assets/33a59a32672847a1afd83bd705babfddadb397b4af23f240f5ea7c72092f9e1b.png
# 1011
# https://storage.googleapis.com/sentinel-nft/raw-assets/5cd6c1a5af7d81833736bcc1ce6bf93f0b9a5d91162a37980a3af6b175dd9b3b.png
# type Female
# accessory Stringy Hair
# accessory Earring
# accessory 2 attributes
# 1012
# https://storage.googleapis.com/sentinel-nft/raw-assets/86bec949504e4d890c993e1ca2d294b1e98caaeae4169afcaf157a5c28feb440.png
# type Male
# accessory Eye Patch
# accessory Mohawk Thin
# accessory 2 attributes
# 1013
# https://storage.googleapis.com/sentinel-nft/raw-assets/686b5778cd6a3af1c24cace16ed61b29cf1c69f7cb2dff3856729ab2ed0cdcd8.png
# type Male
# accessory Clown Eyes Green
# accessory Fedora
# 1014
# https://storage.googleapis.com/sentinel-nft/raw-assets/ab7554859ecc1f66c7460552640ea95ee85a8110bdb32894e54077ff743d316d.png
# type Male
# accessory Luxurious Beard
# accessory Cap Forward
# 1015
# https://storage.googleapis.com/sentinel-nft/raw-assets/f789f5cf22367debc206494c71e870a3740db4ca39ed17ac2897fecdd35924c4.png
# type Female
# accessory Messy Hair
# accessory Silver Chain
# 1016
# https://storage.googleapis.com/sentinel-nft/raw-assets/abe4eeac98342aae305741113f8eab59bcc4cc7c38aca30b2e88f2f685553b90.png
# 1017
# https://storage.googleapis.com/sentinel-nft/raw-assets/b4ad7a3effab14fc44efe02583aed8b51f169dcc9ff264558f65373b81daa928.png
# type Male
# accessory Mole
# accessory Goat
# accessory Top Hat
# 1018
# https://storage.googleapis.com/sentinel-nft/raw-assets/d2cf87d4390f9bcaf78edcda99b555af18e0c76c0eb8efeef32a287252a84b89.png
# type Male
# accessory Front Beard
# accessory Top Hat
# 1019
# https://storage.googleapis.com/sentinel-nft/raw-assets/e33206ff675aa24dd53e12fb4f5bcc43df904deefaf7e9c9d32c0836a9a3f5c3.png
# type Male
# accessory Chinstrap
# accessory Regular Shades
# accessory Headband
# 102
# https://storage.googleapis.com/sentinel-nft/raw-assets/3c2342d8a09cccff5437d64d82b21b17e50b9a1c639e1b6ae2fed89a977f0068.png
# type Male
# accessory Vampire Hair
# accessory Luxurious Beard
# accessory 2 attributes
# 1020
# https://storage.googleapis.com/sentinel-nft/raw-assets/3a3545159bb8b22ad8e77d695adf8cb95aeb71b9edb94897c316c7c35540db91.png
# 1021
# https://storage.googleapis.com/sentinel-nft/raw-assets/bdc3e855c600b0b28b92959e3c9f7fecdd1161fb49cfa1d9f874498bb22f3b10.png
# accessory Cap
# accessory Eye Patch
# type Ape
# accessory 2 attributes
# 1022
# https://storage.googleapis.com/sentinel-nft/raw-assets/701f80fb0d947fa315308617fb617446cc5fd9d4b1a5d575c426ce8636c6702f.png
# type Male
# accessory Mole
# accessory Mohawk Thin
# accessory 2 attributes
# 1023
# https://storage.googleapis.com/sentinel-nft/raw-assets/6286cc87273ccdba0a5216200ce50fde8353dbebcb7353a8818c155b17594fa2.png
# type Female
# accessory Hot Lipstick
# accessory Headband
# 1024
# https://storage.googleapis.com/sentinel-nft/raw-assets/798a96a1596ff509e0d87c4401052281865d4ac91e47a0c8c733b47f9276748b.png
# type Female
# accessory Earring
# accessory Hot Lipstick
# accessory Wild Hair
# accessory Clown Eyes Blue
# 1025
# https://storage.googleapis.com/sentinel-nft/raw-assets/efc77197b5c76f92ce06018e03ed214e1c31e6e949771a6fb2a0dedec9e056ed.png
# type Male
# accessory Earring
# accessory Bandana
# accessory 2 attributes
# 1026
# https://storage.googleapis.com/sentinel-nft/raw-assets/75b2f96339b625c80385ec6c298c5221e3b20d4034742a0349ed9785b5099eda.png
# type Male
# accessory Peak Spike
# accessory Mole
# accessory Clown Eyes Blue
# accessory 3 attributes
# 1027
# https://storage.googleapis.com/sentinel-nft/raw-assets/0e56b5776831702ace9742e19f2691522944abcde2453ac7a405041b3fda8e14.png
# 1028
# https://storage.googleapis.com/sentinel-nft/raw-assets/e8265bebb86d914ca19d34714165d228a03615bae51c677369071e790e85aaf8.png
# type Male
# accessory Big Shades
# accessory Mohawk Thin
# 1029
# https://storage.googleapis.com/sentinel-nft/raw-assets/f3b9d3ca806e9cc229bfd2d9e074769431b6c515cf11baae6cb197c1c5002deb.png
# type Male
# accessory Horned Rim Glasses
# accessory Mustache
# accessory 2 attributes
# 103
# https://storage.googleapis.com/sentinel-nft/raw-assets/9e1b7d545fcf90807f7fd89206056b5fcf2a37c8465be1791e8d61d771a2d70e.png
# type Female
# accessory Green Eye Shadow
# accessory Black Lipstick
# accessory Blonde Bob
# 1030
# https://storage.googleapis.com/sentinel-nft/raw-assets/388fe7ab642f37aaf51fffd4482181c07be3203740dc86f789e284a8d3e4dec7.png
# type Male
# accessory Muttonchops
# accessory Fedora
# 1031
# https://storage.googleapis.com/sentinel-nft/raw-assets/17bf9de8d5db10ea5d3c02c7034f676f45ed5d77c215fac9aae2bc8abc900c94.png
# type Male
# accessory Small Shades
# accessory Cap Forward
# accessory 2 attributes
# 1032
# https://storage.googleapis.com/sentinel-nft/raw-assets/fbc3b96ac5cfae832e1ef89d4d42d6415934f827842d9d76143d3daae01cf5a3.png
# type Female
# accessory Nerd Glasses
# accessory Straight Hair Dark
# 1033
# https://storage.googleapis.com/sentinel-nft/raw-assets/1ff1e1c6ad79c9d8850fddba0049a604c2e2cb815d9075a88c646e8d13d7049c.png
# type Female
# accessory Messy Hair
# accessory Hot Lipstick
# 1034
# https://storage.googleapis.com/sentinel-nft/raw-assets/7a543f98f88f0ae81cfc249eb772a16dc65c3fa5c2a7bf28b2dd735f2ac37945.png
# type Male
# accessory Earring
# accessory Big Shades
# accessory Hoodie
# accessory Normal Beard Black
# 1035
# https://storage.googleapis.com/sentinel-nft/raw-assets/3fb065f69e5e67b5060a366d8ef053b5f0aa421900b96582dff32046039806a0.png
# type Female
# accessory Black Lipstick
# accessory Wild Hair
# 1036
# https://storage.googleapis.com/sentinel-nft/raw-assets/bb8df236dfd87cff21b4e5ea74ac9271d5596de0a59b3c20b5ebf04b389a1ef7.png
# type Male
# accessory Classic Shades
# accessory Mohawk Thin
# accessory 2 attributes
# 1037
# https://storage.googleapis.com/sentinel-nft/raw-assets/d527ca65428db5cd8b236ce2513a075a2b0fbd6fd4a5d6350597789e0545499a.png
# type Female
# accessory Blue Eye Shadow
# accessory Orange Side
# accessory 2 attributes
# 1038
# https://storage.googleapis.com/sentinel-nft/raw-assets/9a2b9716502c807fdf1f40d3349bc586eab05bc7480a0d1f2cfb36c31a6e306b.png
# 1039
# https://storage.googleapis.com/sentinel-nft/raw-assets/c66ea85698d371352190a8ad2df3b86962c649006cc5ef77d2fc3eaa602a4371.png
# type Female
# accessory Messy Hair
# accessory Hot Lipstick
# accessory Clown Eyes Blue
# 104
# https://storage.googleapis.com/sentinel-nft/raw-assets/b4a4b672384c599d7dce9c8a24a18703111d9c59ba1ad42041686b4bdf0df525.png
# type Male
# accessory Earring
# accessory Eye Patch
# accessory Normal Beard Black
# accessory Crazy Hair
# accessory 4 attributes
# 1040
# https://storage.googleapis.com/sentinel-nft/raw-assets/7814b42b4464fe43278ebb97a382b77feb32dcf8ac82678117e0dcadd06be75f.png
# type Female
# accessory Earring
# accessory Mohawk Dark

# %% [markdown]
# ## Full Dataset

# %%
df = pd.DataFrame(columns=["image_id", "trait_type", "value"])

for i in range(1, 202):
    URL = f"https://api.nftport.xyz/v0/nfts/{CRYPTOPUNKS_ADDRESS}?chain=ethereum&page_number={i}&include=metadata"
    res = requests.get(URL, headers={"Authorization": KEY_NFTPORT})

    for nft in res.json()["nfts"]:
        nft_id = nft["token_id"]
        try:
            image_url = nft["cached_file_url"]
            img_data = requests.get(image_url).content
            with open(f'images/cryptopunks/{nft_id}.jpg', 'wb') as handler:
                handler.write(img_data)

            for attr in nft["metadata"]["attributes"]:
                df = df.append({
                    "image_id": nft_id, 
                    "trait_type": attr["trait_type"], 
                    "value": attr["value"]},
                    ignore_index=True)
        except:
            continue
    
df.to_csv('cryptopunks.csv')
